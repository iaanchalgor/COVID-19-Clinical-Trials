# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = r"C:\Users\Dell\OneDrive\Desktop\Projects\COVID-19\COVID clinical trials.csv"
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Enrollment                   34
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Results First Posted       5747
# Last Update Posted            0
# Locations                   585
# Study Documents            5601
# URL                           0
# dtype: int64

# %%
df.shape
# Out:
# (5783, 27)

# %%
df['Acronym'] = df['Acronym'].fillna("No Acronym")

# %%
df['Interventions'] = df['Interventions'].fillna(" No Intervention Reported ")

# %%
df['Outcome Measures'] = df['Outcome Measures'].fillna("Not Reported")

# %%
df['Gender'] = df['Gender'].fillna("Not Reported")

# %%
df['Phases'] = df['Phases'].fillna("Not Applicable")

# %%
df['Enrollment'] = df['Enrollment'].fillna("Unknown")

# %%
df['Study Designs'] = df['Study Designs'].fillna("Not Reported")

# %%
df['Other IDs'] = df['Other IDs'].fillna("None")

# %%
df['Start Date'] = df['Start Date'].fillna("Unknown")

# %%
df['Primary Completion Date'] = df['Primary Completion Date'].fillna("Not Available")

# %%
df['Completion Date'] = df['Completion Date'].fillna("Not Available")

# %%
df = df.drop(columns=['Results First Posted'])

# %%
df = df.drop(columns=['Study Documents'])

# %%
df['Locations'] = df['Locations'].fillna("Unknown")

# %%
df.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Last Update Posted', 'Locations', 'URL'],
#       dtype='object')

# %%
df.shape
# Out:
# (5783, 25)

# %%
df.isnull().sum()
# Out:
# Rank                       0
# NCT Number                 0
# Title                      0
# Acronym                    0
# Status                     0
# Study Results              0
# Conditions                 0
# Interventions              0
# Outcome Measures           0
# Sponsor/Collaborators      0
# Gender                     0
# Age                        0
# Phases                     0
# Enrollment                 0
# Funded Bys                 0
# Study Type                 0
# Study Designs              0
# Other IDs                  0
# Start Date                 0
# Primary Completion Date    0
# Completion Date            0
# First Posted               0
# Last Update Posted         0
# Locations                  0
# URL                        0
# dtype: int64

# %%
#EDA FOR ACRONYM

df['Acronym'].unique()
# Out:
# array(['COVID-IDNow', 'COVID-19', 'TAC-COVID19', ..., 'CRISP', 'cSLE',
#        'MindMyMindFU'], dtype=object)

# %%
num_unique = df['Acronym'].nunique()
print(f"Number of unique acronyms: {num_unique}")
# Out:
# Number of unique acronyms: 2339

# %%
acronym_counts = df['Acronym'].value_counts()
print(acronym_counts)
# Out:
# Acronym
# No Acronym      3303
# COVID-19          47
# PROTECT            7
# CORONA             6
# RECOVER            5
#                 ...
# ASD                1
# VICO               1
# LICORNE            1
# LOSVID             1
# MindMyMindFU       1
# Name: count, Length: 2339, dtype: int64

# %%
acronym_counts.head(10).plot(kind='bar',figsize=(10,5),title="Top 10 Acronyms")
plt.xlabel('Acronym')
plt.ylabel('Count')
plt.show()

# %%
#EDA FOR INTERVATIONS

df['Interventions'].unique()
# Out:
# array(['Diagnostic Test: ID Now™ COVID-19 Screening Test',
#        'Drug: Drug COVID19-0001-USR|Drug: normal saline',
#        'Other: Lung CT scan analysis in COVID-19 patients', ...,
#        'Other: Antibiotic treatment|Other: No antibiotic treatment',
#        'Behavioral: Yoga',
#        'Behavioral: Brief Cognitive Behavioral Therapy for Chronic Pain (BCBT-CP)|Other: BCBT-CP Booster'],
#       dtype=object)

# %%
Interventions_num = df['Interventions'].nunique()
print(f"Number of Unique Interventions:{Interventions_num}")
# Out:
# Number of Unique Interventions:4338

# %%
Interventions_count = df['Interventions'].value_counts()
print(Interventions_count)
# Out:
# Interventions
#  No Intervention Reported                                                                           886
# Other: No intervention                                                                               32
# Other: Questionnaire                                                                                 24
# Other: Survey                                                                                        17
# Drug: Hydroxychloroquine                                                                             16
#                                                                                                    ...
# Drug: Losartan 50 mg and Spironolactone 25 mg pillules oral use                                       1
# Diagnostic Test: Asynchronies detection                                                               1
# Drug: N-acetylcysteine|Other: Peripheral Blood                                                        1
# ...

# %%
top_interventions = Interventions_count.head(10)

plt.figure(figsize=(10,5))
top_interventions.plot(kind='bar', color='lightgreen')
plt.title('Top 10 Interventions')
plt.xlabel('Intervention')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df['Outcome Measures'].nunique()
# Out:
# 5688

# %%
top_outcomes = df['Outcome Measures'].value_counts().head(10)
print(top_outcomes)
# Out:
# Outcome Measures
# Not Reported                                                                                                                                                                      35
# Mortality                                                                                                                                                                          5
# Hospitalization                                                                                                                                                                    4
# Time to clinical improvement|Mortality|SpO2 Improvement|Incidence of new mechanical ventilation use|Duration of hospitalization|Cumulative incidence of serious adverse events     4
# can or can't fell bitterness                                                                                                                                                       3
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
top_outcomes.plot(kind='bar', color='salmon')
plt.title('Top 10 Outcome Measures')
plt.xlabel('Outcome Measure')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
from wordcloud import WordCloud

text = " ".join(df['Outcome Measures'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(15,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
phase_counts = df['Phases'].value_counts()
print(phase_counts)
# Out:
# Phases
# Not Applicable     3815
# Phase 2             685
# Phase 3             450
# Phase 1             234
# Phase 2|Phase 3     200
# Phase 1|Phase 2     192
# Phase 4             161
# Early Phase 1        46
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,8))
phase_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, shadow=True)
plt.title('Distribution of Clinical Trial Phases')
plt.ylabel('')  # Remove default y-label
plt.show()

# %%
plt.figure(figsize=(15,5))
phase_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Studies by Phase')
plt.xlabel('Phase')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
print(df['Enrollment'].describe())
# Out:
# count     5783.0
# unique     963.0
# top        100.0
# freq       350.0
# Name: Enrollment, dtype: float64

# %%
# Convert to numeric, invalid parsing will become NaN
df['Enrollment'] = pd.to_numeric(df['Enrollment'], errors='coerce')

# Check how many values are now NaN
print(df['Enrollment'].isna().sum())
# Out:
# 34

# %%
import matplotlib.pyplot as plt

enrollment_clean = df['Enrollment'].dropna()

# Boxplot
plt.figure(figsize=(8,5))
plt.boxplot(enrollment_clean)
plt.title('Boxplot of Enrollment')
plt.ylabel('Number of Participants')
plt.show()

# Histogram
plt.figure(figsize=(10,5))
plt.hist(enrollment_clean, bins=30, color='skyblue')
plt.title('Distribution of Enrollment')
plt.xlabel('Number of Participants')
plt.ylabel('Count')
plt.show()

# %%
study_design_counts = df['Study Designs'].value_counts()
print(study_design_counts)
# Out:
# Study Designs
# Observational Model: Cohort|Time Perspective: Prospective                                                                                                                     1011
# Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: None (Open Label)|Primary Purpose: Treatment                                                           572
# Allocation: Randomized|Intervention Model: Parallel Assignment|Masking: Quadruple (Participant, Care Provider, Investigator, Outcomes Assessor)|Primary Purpose: Treatment     312
# Observational Model: Cohort|Time Perspective: Retrospective                                                                                                                    282
# Allocation: N/A|Intervention Model: Single Group Assignment|Masking: None (Open Label)|Primary Purpose: Treatment                                                              241
# ...

# %%
import matplotlib.pyplot as plt

# Take top 10 study designs
top_study_designs = study_design_counts.head(10)

plt.figure(figsize=(10,5))
top_study_designs.plot(kind='bar', color='lightgreen')
plt.title('Top 10 Study Designs')
plt.xlabel('Study Design')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Check uniqueness
print(f"Total IDs: {len(df['Other IDs'])}")
print(f"Unique IDs: {df['Other IDs'].nunique()}")

# Check duplicates
duplicates = df['Other IDs'].duplicated().sum()
print(f"Number of duplicate Other IDs: {duplicates}")
# Out:
# Total IDs: 5783
# Unique IDs: 5735
# Number of duplicate Other IDs: 48

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'], errors='coerce')
df['Primary Completion Date'] = pd.to_datetime(df['Primary Completion Date'], errors='coerce')

# %%
df['Study Duration (days)'] = (df['Primary Completion Date'] - df['Start Date']).dt.days

# %%
print(df['Study Duration (days)'].describe())
# Out:
# count     4294.000000
# mean       310.634606
# std        608.981959
# min          0.000000
# 25%         88.250000
# 50%        189.000000
# 75%        365.000000
# max      29119.000000
# Name: Study Duration (days), dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.hist(df['Study Duration (days)'].dropna(), bins=30, color='orange')
plt.title('Distribution of Study Duration')
plt.xlabel('Duration (days)')
plt.ylabel('Number of Studies')
plt.show()

# %%
df['Start Year'] = df['Start Date'].dt.year
studies_per_year = df['Start Year'].value_counts().sort_index()

# %%
plt.figure(figsize=(10,5))
studies_per_year.plot(kind='line', marker='o', color='blue')
plt.title('Number of Studies Started Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Studies')
plt.grid(True)
plt.show()

# %%
df['Conditions'].unique()
# Out:
# array(['Covid19', 'SARS-CoV-2 Infection', 'covid19', ...,
#        'Community Acquired Pneumonia in Children|Antibiotic Stewardship',
#        'Stress|Psychological',
#        'Emotional Problem|Anxiety Disorder of Childhood|Depressive Symptoms|Behavior Problem of Childhood and Adolescence|Mental Health Disorder'],
#       dtype=object)

# %%
df['Conditions'].nunique()
# Out:
# 3067

# %%
top_conditions = df['Conditions'].value_counts().head(10)
print(top_conditions)
# Out:
# Conditions
# COVID-19                  720
# Covid19                   657
# COVID                      95
# Covid-19                   88
# SARS-CoV-2                 52
# Coronavirus Infection      51
# Coronavirus                47
# COVID 19                   46
# COVID19                    45
# Corona Virus Infection     38
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
top_conditions.plot(kind='bar', color='skyblue')
plt.title('Top 10 Conditions')
plt.xlabel('Condition')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()
